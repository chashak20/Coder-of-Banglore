# %% [markdown]
# #Coders of Banglore
#
# You ask Sam Altman for 2.2 billion USD in funding, and he makes fun of you in public
#
# He asks you where you live, and finally, after talking to you, gives you a challenging task
#
# Collect raw Instagram data of all OpenAI followers
#
# Answer these questions:
#
# .Who has the maximum posts
# .who has the maximum followers
# .Who follows the maximum people
# .How many categories (Digital creators, Non-profit foundation, etc do we have? How many people do we have?
# You have 24 hours!
#
# You then ask for data - he laughs!

# %%
# Data Collection in Indiranagar

You hire Vijyalaxmi Iyer and Sam Chandra to help with the project.
Vijyalaxmi lives all the way in Hebbal, and Sam stays in HSR Layout, so meeting at either place would be a long trip for someone. To keep things fair, you decide to set up a meeting at Rameshwaram Café in Indiranagar, a perfect midway point.

Three of you sit down and lay out the entire project plan. You break the work into two major parts:

Laxmi and Sam will be in charge of collecting the Instagram follower data.
You will build the Python Script that will process everything.
By the end of the meeting, everyone is aligned: Laxmi and Sam will focus on accurate data collection, and you’ll focus on making sure the code can handle real-world data seamlessly. The team is ready, the plan is set, and the project officially kicks off.

# %%
with open("initialdata.txt",encoding='utf-8') as f:
    data=f.read()

# %%
data
# Out:
# "intaglobal\n1,946 posts\n6,851 followers\n262 following\nINTA\nNonprofit organization\nThe association of ™ professionals.\ninta.campsite.bio\n\n_anujsinghal\n1,785 posts\n681K followers\n248 following\nAnuj Singhal\nDigital creator\nManaging Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet’s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul\n\ncode_flare\n165 posts\n216 followers\n10 following\nThe Journey Notebook | Travel | Food Blogger\nBlogger\n📍 Exploring places & phases of life 🌍\n.\n🍵 From chai breaks to flight takes ✈️\n.\n💫 Travel | Food | Daily life 🌸\nyoutube.com/@thejourneynotebook?si=Z1lPUAl-cPgHAP_a\n\nbangalore_tech_bro\n402 posts\n12.5K followers\n890 following\nRahul | HSR Hustler\nEntrepreneur\n🚀 Building the next Unicorn in Fintech\n☕ 3rd Wave Coffee addict\n💻 Python | React | AI\n📍 HSR Layout, BLR\nlinktr.ee/rahulbuilds\n\nsilkboard_survivor\n55 posts\n1,200 followers\n50 following\nPriya D.\nPublic Figure\n🚦 Stuck in traffic since 2019\n🌧️ Loving the Bangalore weather, hating the cabs\n🐍 Data Scientist by day, meme maker by night\n📍 ORR\nbit.ly/my-traffic-rants\n\nstartuphub_blr\n2,300 posts\n45K followers\n120 following\nStartup Hub Bangalore\nMedia\n🦄 News from the Silicon Valley of India\n📢 Funding alerts, Hiring trends, and Drama\n📩 DM for features\nstartuphub.blr/newsletter\n\nfoodie_in_kora\n890 posts\n5,600 followers\n400 following\nSneha | Bangalore Eats\nFood & Drink\nAagrah to Truffles 🍔\nExploring Koramangala's cafe culture ☕\nDM for collabs\nhttps://www.google.com/search?q=zomato.com/users/sneha123\n\nventure_vikram\n120 posts\n30K followers\n500 following\nVikram | Angel Investor\nInvestor\n💸 Helping founders go 0 to 1\nEx-Google, Ex-Amazon\nInvesting in DeepTech & AI\n📍 Indiranagar\nvikram.vc/pitch-deck\n\npython_meetup_blr\n60 posts\n3,400 followers\n10 following\nPyBangalore Community\nCommunity\n🐍 Weekly meetups for Pythonistas\n📍 Cubbon Park | Sundays 4 PM\nCoding + Coffee + Community\nhttps://www.google.com/search?q=meetup.com/pybangalore\n\nindiranagar_gossip\n300 posts\n8,900 followers\n20 following\nIndiranagar Spy\nPersonal Blog\nNot just about 100ft Road 🤫\nSpilling tea on the best brunches and worst landlords\nBengaluru\nhttps://www.google.com/search?q=medium.com/%40indiranagarspy\n\n\nig_arbin07\n50 posts\n33 followers\n30 following\naarbinnn\nGamer\n@dumb.arbin\n🎮: Banana『juice (IGL🥷)\nGamer never die, they just respawn🙂\u200d↔️\n\n\n\n7iiuliiu\n1 post\n44 followers\n166 following\n︎𝐄︎ ♡︎.\n\n\nkatiasales2220\n107 posts\n219 followers\n1,401 following\nKatia Sales\nAlfabetização e Reforço Escolar\nEnsino Fundamental I e II\nPreparação para Escola Militar\nPortuguês e Matemática\nCursando Psicopedagogia Estácio"

# %%
chunks=data.split("\n\n")
chunks = [c for c in chunks if len(c)>3]
chunks
# Out:
# ['intaglobal\n1,946 posts\n6,851 followers\n262 following\nINTA\nNonprofit organization\nThe association of ™ professionals.\ninta.campsite.bio',
#  '_anujsinghal\n1,785 posts\n681K followers\n248 following\nAnuj Singhal\nDigital creator\nManaging Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet’s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul',
#  'code_flare\n165 posts\n216 followers\n10 following\nThe Journey Notebook | Travel | Food Blogger\nBlogger\n📍 Exploring places & phases of life 🌍\n.\n🍵 From chai breaks to flight takes ✈️\n.\n💫 Travel | Food | Daily life 🌸\nyoutube.com/@thejourneynotebook?si=Z1lPUAl-cPgHAP_a',
#  'bangalore_tech_bro\n402 posts\n12.5K followers\n890 following\nRahul | HSR Hustler\nEntrepreneur\n🚀 Building the next Unicorn in Fintech\n☕ 3rd Wave Coffee addict\n💻 Python | React | AI\n📍 HSR Layout, BLR\nlinktr.ee/rahulbuilds',
#  'silkboard_survivor\n55 posts\n1,200 followers\n50 following\nPriya D.\nPublic Figure\n🚦 Stuck in traffic since 2019\n🌧️ Loving the Bangalore weather, hating the cabs\n🐍 Data Scientist by day, meme maker by night\n📍 ORR\nbit.ly/my-traffic-rants',
#  'startuphub_blr\n2,300 posts\n45K followers\n120 following\nStartup Hub Bangalore\nMedia\n🦄 News from the Silicon Valley of India\n📢 Funding alerts, Hiring trends, and Drama\n📩 DM for features\nstartuphub.blr/newsletter',
#  "foodie_in_kora\n890 posts\n5,600 followers\n400 following\nSneha | Bangalore Eats\nFood & Drink\nAagrah to Truffles 🍔\nExploring Koramangala's cafe culture ☕\nDM for collabs\nhttps://www.google.com/search?q=zomato.com/users/sneha123",
#  'venture_vikram\n120 posts\n30K followers\n500 following\nVikram | Angel Investor\nInvestor\n💸 Helping founders go 0 to 1\nEx-Google, Ex-Amazon\nInvesting in DeepTech & AI\n📍 Indiranagar\nvikram.vc/pitch-deck',
#  'python_meetup_blr\n60 posts\n3,400 followers\n10 following\nPyBangalore Community\nCommunity\n🐍 Weekly meetups for Pythonistas\n📍 Cubbon Park | Sundays 4 PM\nCoding + Coffee + Community\nhttps://www.google.com/search?q=meetup.com/pybangalore',
#  'indiranagar_gossip\n300 posts\n8,900 followers\n20 following\nIndiranagar Spy\nPersonal Blog\nNot just about 100ft Road 🤫\nSpilling tea on the best brunches and worst landlords\nBengaluru\nhttps://www.google.com/search?q=medium.com/%40indiranagarspy',
#  '\nig_arbin07\n50 posts\n33 followers\n30 following\naarbinnn\nGamer\n@dumb.arbin\n🎮: Banana『juice (IGL🥷)\nGamer never die, they just respawn🙂\u200d↔️',
#  '7iiuliiu\n1 post\n44 followers\n166 following\n︎𝐄︎ ♡︎.',
#  '\nkatiasales2220\n107 posts\n219 followers\n1,401 following\nKatia Sales\nAlfabetização e Reforço Escolar\nEnsino Fundamental I e II\nPreparação para Escola Militar\nPortuguês e Matemática\nCursando Psicopedagogia Estácio']

# %%
chunks[4]
# Out:
# 'silkboard_survivor\n55 posts\n1,200 followers\n50 following\nPriya D.\nPublic Figure\n🚦 Stuck in traffic since 2019\n🌧️ Loving the Bangalore weather, hating the cabs\n🐍 Data Scientist by day, meme maker by night\n📍 ORR\nbit.ly/my-traffic-rants'

# %%
def parse_chunk(chunk): 
        chunk = chunk.strip()
        sep_chunk = chunk.split('\n')
        username = sep_chunk[0]
        no_of_posts = int(sep_chunk[1].split(" post")[0].replace(",",""))
        no_of_followers = float(sep_chunk[2].split(" follower")[0].replace(",","").replace("K","").replace("M",""))
        if("K" in sep_chunk[2]):
            no_of_followers = int(no_of_followers * 1000)
        elif("M" in sep_chunk[2]):
            no_of_followers = int(no_of_followers * 1000000)
    
        else:
            no_of_followers = int(no_of_followers)

        no_of_following = float(sep_chunk[3].split(" following")[0].replace(",","").replace("K","").replace("M",""))
        if("K" in sep_chunk[3]):
            no_of_following = int(no_of_following * 1000)
        elif("M" in sep_chunk[3]):
            no_of_following = int(no_of_following * 1000000)
    
        else:
            no_of_following = int(no_of_following)

    
        name = sep_chunk[4]
        if(len(sep_chunk)> 5):
            type_of_page = sep_chunk[5]
            bio = "\n".join(sep_chunk[6:])
        else:
            type_of_page = "Unknown"
            bio = ""
        # print(username, no_of_posts, no_of_followers, no_of_following, name, type_of_page, bio, sep="\n")
        return {"username": username, "no_of_posts": no_of_posts, "no_of_followers": no_of_followers, 
                "no_of_following": no_of_following, "name": name, "type_of_page": type_of_page, "bio": bio}

# print(parse_chunk(chunks[0]))

# %%
all_chunks = [] 
for chunk in chunks:  
    parsed_chunk = parse_chunk(chunk)
    all_chunks.append(parsed_chunk)
print(all_chunks)
# Out:
# [{'username': 'intaglobal', 'no_of_posts': 1946, 'no_of_followers': 6851, 'no_of_following': 262, 'name': 'INTA', 'type_of_page': 'Nonprofit organization', 'bio': 'The association of ™ professionals.\ninta.campsite.bio'}, {'username': '_anujsinghal', 'no_of_posts': 1785, 'no_of_followers': 681000, 'no_of_following': 248, 'name': 'Anuj Singhal', 'type_of_page': 'Digital creator', 'bio': 'Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet’s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul'}, {'username': 'code_flare', 'no_of_posts': 165, 'no_of_followers': 216, 'no_of_following': 10, 'name': 'The Journey Notebook | Travel | Food Blogger', 'type_of_page': 'Blogger', 'bio': '📍 Exploring places & phases of life 🌍\n.\n🍵 From chai breaks to flight takes ✈️\n.\n💫 Travel | Food | Daily life 🌸\nyoutube.com/@thejourneynotebook?si=Z1lPUAl-cPgHAP_a'}, {'username': 'bangalore_tech_bro', 'no_of_posts': 402, 'no_of_followers': 12500, 'no_of_following': 890, 'name': 'Rahul | HSR Hustler', 'type_of_page': 'Entrepreneur', 'bio': '🚀 Building the next Unicorn in Fintech\n☕ 3rd Wave Coffee addict\n💻 Python | React | AI\n📍 HSR Layout, BLR\nlinktr.ee/rahulbuilds'}, {'username': 'silkboard_survivor', 'no_of_posts': 55, 'no_of_followers': 1200, 'no_of_following': 50, 'name': 'Priya D.', 'type_of_page': 'Public Figure', 'bio': '🚦 Stuck in traffic since 2019\n🌧️ Loving the Bangalore weather, hating the cabs\n🐍 Data Scientist by day, meme maker by night\n📍 ORR\nbit.ly/my-traffic-rants'}, {'username': 'startuphub_blr', 'no_of_posts': 2300, 'no_of_followers': 45000, 'no_of_following': 120, 'name': 'Startup Hub Bangalore', 'type_of_page': 'Media', 'bio': '🦄 News from the Silicon Valley of India\n📢 Funding alerts, Hiring trends, and Drama\n📩 DM for features\nstartuphub.blr/newsletter'}, {'username': 'foodie_in_kora', 'no_of_posts': 890, 'no_of_followers': 5600, 'no_of_following': 400, 'name': 'Sneha | Bangalore Eats', 'type_of_page': 'Food & Drink', 'bio': "Aagrah to Truffles 🍔\nExploring Koramangala's cafe culture ☕\nDM for collabs\nhttps://www.google.com/search?q=zomato.com/users/sneha123"}, {'username': 'venture_vikram', 'no_of_posts': 120, 'no_of_followers': 30000, 'no_of_following': 500, 'name': 'Vikram | Angel Investor', 'type_of_page': 'Investor', 'bio': '💸 Helping founders go 0 to 1\nEx-Google, Ex-Amazon\nInvesting in DeepTech & AI\n📍 Indiranagar\nvikram.vc/pitch-deck'}, {'username': 'python_meetup_blr', 'no_of_posts': 60, 'no_of_followers': 3400, 'no_of_following': 10, 'name': 'PyBangalore Community', 'type_of_page': 'Community', 'bio': '🐍 Weekly meetups for Pythonistas\n📍 Cubbon Park | Sundays 4 PM\nCoding + Coffee + Community\nhttps://www.google.com/search?q=meetup.com/pybangalore'}, {'username': 'indiranagar_gossip', 'no_of_posts': 300, 'no_of_followers': 8900, 'no_of_following': 20, 'name': 'Indiranagar Spy', 'type_of_page': 'Personal Blog', 'bio': 'Not just about 100ft Road 🤫\nSpilling tea on the best brunches and worst landlords\nBengaluru\nhttps://www.google.com/search?q=medium.com/%40indiranagarspy'}, {'username': 'ig_arbin07', 'no_of_posts': 50, 'no_of_followers': 33, 'no_of_following': 30, 'name': 'aarbinnn', 'type_of_page': 'Gamer', 'bio': '@dumb.arbin\n🎮: Banana『juice (IGL🥷)\nGamer never die, they just respawn🙂\u200d↔️'}, {'username': '7iiuliiu', 'no_of_posts': 1, 'no_of_followers': 44, 'no_of_following': 166, 'name': '︎𝐄︎ ♡︎.', 'type_of_page': 'Unknown', 'bio': ''}, {'username': 'katiasales2220', 'no_of_posts': 107, 'no_of_followers': 219, 'no_of_following': 1401, 'name': 'Katia Sales', 'type_of_page': 'Alfabetização e Reforço Escolar', 'bio': 'Ensino Fundamental I e II\nPreparação para Escola Militar\nPortuguês e Matemática\nCursando Psicopedagogia Estácio'}]

# %%
import json
s=json.dumps(all_chunks, indent=4)
print(s)
# Out:
# [
#     {
#         "username": "intaglobal",
#         "no_of_posts": 1946,
#         "no_of_followers": 6851,
#         "no_of_following": 262,
#         "name": "INTA",
#         "type_of_page": "Nonprofit organization",
#         "bio": "The association of \u2122 professionals.\ninta.campsite.bio"
#     },
#     {
#         "username": "_anujsinghal",
#         "no_of_posts": 1785,
#         "no_of_followers": 681000,
#         "no_of_following": 248,
#         "name": "Anuj Singhal",
#         "type_of_page": "Digital creator",
#         "bio": "Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet\u2019s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul"
#     },
#     {
#         "username": "code_flare",
#         "no_of_posts": 165,
#         "no_of_followers": 216,
#         "no_of_following": 10,
#         "name": "The Journey Notebook | Travel | Food Blogger",
#         "type_of_page": "Blogger",
#         "bio": "\ud83d\udccd Exploring places & phases of life \ud83c\udf0d\n.\n\ud83c\udf75 From chai breaks to flight takes \u2708\ufe0f\n.\n\ud83d\udcab Travel | Food | Daily life \ud83c\udf38\nyoutube.com/@thejourneynotebook?si=Z1lPUAl-cPgHAP_a"
#     },
#     {
#         "username": "bangalore_tech_bro",
#         "no_of_posts": 402,
#         "no_of_followers": 12500,
#         "no_of_following": 890,
#         "name": "Rahul | HSR Hustler",
#         "type_of_page": "Entrepreneur",
#         "bio": "\ud83d\ude80 Building the next Unicorn in Fintech\n\u2615 3rd Wave Coffee addict\n\ud83d\udcbb Python | React | AI\n\ud83d\udccd HSR Layout, BLR\nlinktr.ee/rahulbuilds"
#     },
#     {
#         "username": "silkboard_survivor",
#         "no_of_posts": 55,
#         "no_of_followers": 1200,
#         "no_of_following": 50,
#         "name": "Priya D.",
#         "type_of_page": "Public Figure",
#         "bio": "\ud83d\udea6 Stuck in traffic since 2019\n\ud83c\udf27\ufe0f Loving the Bangalore weather, hating the cabs\n\ud83d\udc0d Data Scientist by day, meme maker by night\n\ud83d\udccd ORR\nbit.ly/my-traffic-rants"
#     },
#     {
#         "username": "startuphub_blr",
#         "no_of_posts": 2300,
#         "no_of_followers": 45000,
#         "no_of_following": 120,
#         "name": "Startup Hub Bangalore",
#         "type_of_page": "Media",
#         "bio": "\ud83e\udd84 News from the Silicon Valley of India\n\ud83d\udce2 Funding alerts, Hiring trends, and Drama\n\ud83d\udce9 DM for features\nstartuphub.blr/newsletter"
#     },
#     {
#         "username": "foodie_in_kora",
#         "no_of_posts": 890,
#         "no_of_followers": 5600,
#         "no_of_following": 400,
#         "name": "Sneha | Bangalore Eats",
#         "type_of_page": "Food & Drink",
#         "bio": "Aagrah to Truffles \ud83c\udf54\nExploring Koramangala's cafe culture \u2615\nDM for collabs\nhttps://www.google.com/search?q=zomato.com/users/sneha123"
#     },
#     {
#         "username": "venture_vikram",
#         "no_of_posts": 120,
#         "no_of_followers": 30000,
#         "no_of_following": 500,
#         "name": "Vikram | Angel Investor",
#         "type_of_page": "Investor",
#         "bio": "\ud83d\udcb8 Helping founders go 0 to 1\nEx-Google, Ex-Amazon\nInvesting in DeepTech & AI\n\ud83d\udccd Indiranagar\nvikram.vc/pitch-deck"
#     },
#     {
#         "username": "python_meetup_blr",
#         "no_of_posts": 60,
#         "no_of_followers": 3400,
#         "no_of_following": 10,
#         "name": "PyBangalore Community",
#         "type_of_page": "Community",
#         "bio": "\ud83d\udc0d Weekly meetups for Pythonistas\n\ud83d\udccd Cubbon Park | Sundays 4 PM\nCoding + Coffee + Community\nhttps://www.google.com/search?q=meetup.com/pybangalore"
#     },
#     {
#         "username": "indiranagar_gossip",
#         "no_of_posts": 300,
#         "no_of_followers": 8900,
#         "no_of_following": 20,
#         "name": "Indiranagar Spy",
#         "type_of_page": "Personal Blog",
#         "bio": "Not just about 100ft Road \ud83e\udd2b\nSpilling tea on the best brunches and worst landlords\nBengaluru\nhttps://www.google.com/search?q=medium.com/%40indiranagarspy"
#     },
#     {
#         "username": "ig_arbin07",
#         "no_of_posts": 50,
#         "no_of_followers": 33,
#         "no_of_following": 30,
#         "name": "aarbinnn",
#         "type_of_page": "Gamer",
#         "bio": "@dumb.arbin\n\ud83c\udfae: Banana\u300ejuice (IGL\ud83e\udd77)\nGamer never die, they just respawn\ud83d\ude42\u200d\u2194\ufe0f"
#     },
#     {
#         "username": "7iiuliiu",
#         "no_of_posts": 1,
#         "no_of_followers": 44,
#         "no_of_following": 166,
#         "name": "\ufe0e\ud835\udc04\ufe0e \u2661\ufe0e.",
#         "type_of_page": "Unknown",
#         "bio": ""
#     },
#     {
#         "username": "katiasales2220",
#         "no_of_posts": 107,
#         "no_of_followers": 219,
#         "no_of_following": 1401,
#         "name": "Katia Sales",
#         "type_of_page": "Alfabetiza\u00e7\u00e3o e Refor\u00e7o Escolar",
#         "bio": "Ensino Fundamental I e II\nPrepara\u00e7\u00e3o para Escola Militar\nPortugu\u00eas e Matem\u00e1tica\nCursando Psicopedagogia Est\u00e1cio"
#     }
# ]

# %%
pip install jupyterlab-git
# Out:
# Collecting jupyterlab-git
#   Downloading jupyterlab_git-0.52.0-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: jupyter-server<3,>=2.0.1 in c:\users\iamch\anaconda3\lib\site-packages (from jupyterlab-git) (2.15.0)
# Collecting nbdime~=4.0.1 (from jupyterlab-git)
#   Downloading nbdime-4.0.4-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: nbformat in c:\users\iamch\anaconda3\lib\site-packages (from jupyterlab-git) (5.10.4)
# Requirement already satisfied: packaging in c:\users\iamch\anaconda3\lib\site-packages (from jupyterlab-git) (24.2)
# Requirement already satisfied: pexpect in c:\users\iamch\anaconda3\lib\site-packages (from jupyterlab-git) (4.8.0)
# Requirement already satisfied: traitlets~=5.0 in c:\users\iamch\anaconda3\lib\site-packages (from jupyterlab-git) (5.14.3)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\iamch\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (4.7.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\iamch\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (21.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\iamch\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\iamch\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\iamch\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\iamch\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\iamch\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\iamch\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (7.16.6)
# Requirement already satisfied: overrides>=5.0 in c:\users\iamch\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\iamch\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\iamch\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (2.0.15)
# Requirement already satisfied: pyzmq>=24 in c:\users\iamch\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (26.2.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\iamch\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\iamch\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (0.17.1)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\iamch\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (6.5.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\iamch\anaconda3\lib\site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (1.8.0)
# Requirement already satisfied: colorama in c:\users\iamch\anaconda3\lib\site-packages (from nbdime~=4.0.1->jupyterlab-git) (0.4.6)
# Requirement already satisfied: gitpython!=2.1.4,!=2.1.5,!=2.1.6 in c:\users\iamch\anaconda3\lib\site-packages (from nbdime~=4.0.1->jupyterlab-git) (3.1.43)
# Requirement already satisfied: pygments in c:\users\iamch\anaconda3\lib\site-packages (from nbdime~=4.0.1->jupyterlab-git) (2.19.1)
# Requirement already satisfied: requests in c:\users\iamch\anaconda3\lib\site-packages (from nbdime~=4.0.1->jupyterlab-git) (2.32.3)
# Requirement already satisfied: idna>=2.8 in c:\users\iamch\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\iamch\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\iamch\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.0.1->jupyterlab-git) (21.2.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\iamch\anaconda3\lib\site-packages (from gitpython!=2.1.4,!=2.1.5,!=2.1.6->nbdime~=4.0.1->jupyterlab-git) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\iamch\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=2.1.4,!=2.1.5,!=2.1.6->nbdime~=4.0.1->jupyterlab-git) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\iamch\anaconda3\lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.0.1->jupyterlab-git) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\iamch\anaconda3\lib\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\iamch\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.0.1->jupyterlab-git) (4.3.7)
# Requirement already satisfied: pywin32>=300 in c:\users\iamch\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.0.1->jupyterlab-git) (308)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\iamch\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (4.23.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\iamch\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (3.2.1)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\iamch\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (6.0.2)
# Requirement already satisfied: referencing in c:\users\iamch\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.30.2)
# Requirement already satisfied: rfc3339-validator in c:\users\iamch\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\iamch\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.1.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\iamch\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\iamch\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (2023.7.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\iamch\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.22.3)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git)
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git)
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\iamch\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (2.1)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git)
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git)
#   Downloading webcolors-25.10.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\iamch\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\iamch\anaconda3\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\iamch\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\iamch\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\iamch\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\iamch\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\iamch\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.5.0)
# Requirement already satisfied: webencodings in c:\users\iamch\anaconda3\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\iamch\anaconda3\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\iamch\anaconda3\lib\site-packages (from nbformat->jupyterlab-git) (2.20.0)
# Requirement already satisfied: six>=1.5 in c:\users\iamch\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.17.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\iamch\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\iamch\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.0.1->jupyterlab-git) (2.21)
# Requirement already satisfied: soupsieve>1.2 in c:\users\iamch\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\iamch\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (4.12.2)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\iamch\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.3.0)
# Requirement already satisfied: ptyprocess>=0.5 in c:\users\iamch\anaconda3\lib\site-packages (from pexpect->jupyterlab-git) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\iamch\anaconda3\lib\site-packages (from requests->nbdime~=4.0.1->jupyterlab-git) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\iamch\anaconda3\lib\site-packages (from requests->nbdime~=4.0.1->jupyterlab-git) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\iamch\anaconda3\lib\site-packages (from requests->nbdime~=4.0.1->jupyterlab-git) (2025.8.3)
# Downloading jupyterlab_git-0.52.0-py3-none-any.whl (370 kB)
# Downloading nbdime-4.0.4-py3-none-any.whl (5.9 MB)
#    ---------------------------------------- 0.0/5.9 MB ? eta -:--:--
#    ----------------------------------- ---- 5.2/5.9 MB 26.0 MB/s eta 0:00:01
#    ---------------------------------------- 5.9/5.9 MB 20.0 MB/s eta 0:00:00
# Downloading webcolors-25.10.0-py3-none-any.whl (14 kB)
# Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Installing collected packages: webcolors, uri-template, fqdn, isoduration, nbdime, jupyterlab-git
#
#    ------ --------------------------------- 1/6 [uri-template]
#    ------------- -------------------------- 2/6 [fqdn]
#    -------------------- ------------------- 3/6 [isoduration]
#    -------------------- ------------------- 3/6 [isoduration]
#    -------------------------- ------------- 4/6 [nbdime]
#    -------------------------- ------------- 4/6 [nbdime]
#    -------------------------- ------------- 4/6 [nbdime]
#    -------------------------- ------------- 4/6 [nbdime]
#    -------------------------- ------------- 4/6 [nbdime]
#    -------------------------- ------------- 4/6 [nbdime]
#    -------------------------- ------------- 4/6 [nbdime]
#    -------------------------- ------------- 4/6 [nbdime]
#    -------------------------- ------------- 4/6 [nbdime]
#    -------------------------- ------------- 4/6 [nbdime]
#    -------------------------- ------------- 4/6 [nbdime]
#    -------------------------- ------------- 4/6 [nbdime]
#    -------------------------- ------------- 4/6 [nbdime]
#    -------------------------- ------------- 4/6 [nbdime]
#    -------------------------- ------------- 4/6 [nbdime]
#    -------------------------- ------------- 4/6 [nbdime]
#    -------------------------- ------------- 4/6 [nbdime]
#    -------------------------- ------------- 4/6 [nbdime]
#    -------------------------- ------------- 4/6 [nbdime]
#    -------------------------- ------------- 4/6 [nbdime]
#    -------------------------- ------------- 4/6 [nbdime]
#    --------------------------------- ------ 5/6 [jupyterlab-git]
#    --------------------------------- ------ 5/6 [jupyterlab-git]
#    --------------------------------- ------ 5/6 [jupyterlab-git]
#    --------------------------------- ------ 5/6 [jupyterlab-git]
#    --------------------------------- ------ 5/6 [jupyterlab-git]
#    ---------------------------------------- 6/6 [jupyterlab-git]
#
# Successfully installed fqdn-1.5.1 isoduration-20.11.0 jupyterlab-git-0.52.0 nbdime-4.0.4 uri-template-1.3.0 webcolors-25.10.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# !git init
# Out:
# Initialized empty Git repository in C:/coders of Banglore/.git/

# %%
# !git add .
# Out:
# warning: in the working copy of '.ipynb_checkpoints/Coders of Banglore-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Coders of Banglore.ipynb', LF will be replaced by CRLF the next time Git touches it

# %%
# !git commit -m "Data collection"
# Out:
# [master (root-commit) c7d124c] Data collection
#  4 files changed, 1708 insertions(+)
#  create mode 100644 .ipynb_checkpoints/Coders of Banglore-checkpoint.ipynb
#  create mode 100644 Coders of Banglore.ipynb
#  create mode 100644 finaldata.txt
#  create mode 100644 initialdata.txt

# %%
# !git remote add origin https://github.com/chashak20/Coder-of-Banglore.git

# %%
# !git branch -M main

# %%
# !git push -u origin main
# Out:
# branch 'main' set up to track 'origin/main'.
# To https://github.com/chashak20/Coder-of-Banglore.git
#  * [new branch]      main -> main

# %% [markdown]
# # who has the maximum posts
#
# Lets write code to find maximum post

# %%
max = 0
for chunk in all_chunks:
    if(max<chunk['no_of_posts']):
        max = chunk['no_of_posts']
        chunk_with_max_post = chunk
print(chunk_with_max_post)
# Out:
# {'username': 'startuphub_blr', 'no_of_posts': 2300, 'no_of_followers': 45000, 'no_of_following': 120, 'name': 'Startup Hub Bangalore', 'type_of_page': 'Media', 'bio': '🦄 News from the Silicon Valley of India\n📢 Funding alerts, Hiring trends, and Drama\n📩 DM for features\nstartuphub.blr/newsletter'}

# %% [markdown]
# # who has the maximum followers
#
# Lets write code to find maximum followers

# %%
max = 0
for chunk in all_chunks:
    if(max<chunk['no_of_followers']):
        max = chunk['no_of_followers']
        chunk_with_max_followers = chunk
print(chunk_with_max_followers)
# Out:
# {'username': '_anujsinghal', 'no_of_posts': 1785, 'no_of_followers': 681000, 'no_of_following': 248, 'name': 'Anuj Singhal', 'type_of_page': 'Digital creator', 'bio': 'Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet’s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul'}

# %% [markdown]
# # Who follows the maximum people
#
# Lets write code to find who follows the maximum people

# %%
max = 0
for chunk in all_chunks:
    if(max<chunk['no_of_following']):
        max = chunk['no_of_following']
        chunk_with_max_following = chunk
print(chunk_with_max_following)
# Out:
# {'username': 'katiasales2220', 'no_of_posts': 107, 'no_of_followers': 219, 'no_of_following': 1401, 'name': 'Katia Sales', 'type_of_page': 'Alfabetização e Reforço Escolar', 'bio': 'Ensino Fundamental I e II\nPreparação para Escola Militar\nPortuguês e Matemática\nCursando Psicopedagogia Estácio'}

# %% [markdown]
# # How many categories (Digital creators, Non-profit foundation, etc do we have? How many people do we have?
#
# Lets write code to find categories we have and how many people

# %%
categories = set()
for chunk in all_chunks:
    categories.add(chunk['type_of_page'])
print(categories, len(categories))
# Out:
# {'Alfabetização e Reforço Escolar', 'Public Figure', 'Unknown', 'Nonprofit organization', 'Digital creator', 'Food & Drink', 'Community', 'Personal Blog', 'Investor', 'Gamer', 'Entrepreneur', 'Blogger', 'Media'} 13
